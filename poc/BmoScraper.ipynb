# %%
import pandas as pd
from bs4 import BeautifulSoup
from keyring import get_password
# import json
from numpy import nan
# from pymongo import MongoClient
# from pymongo.errors import DuplicateKeyError
# from random import sample
from time import sleep
from urllib.error import HTTPError
from urllib.request import urlopen

# %%
class BmoScraper:
    # Pass in note URLs & lookup for PDW
    def __init__(self, bmo_urls, user, password, host, port, options):
        # cxn_string = f"mongodb://{user}:{password}@{host}:{port}/?{options}"
        # self.client = MongoClient(cxn_string)
        self.notes_dict = {}
        self.errors_dict = {}
        for note in bmo_urls:
            try:
                try:
                    try:
                        self.notes_dict[note.rsplit(
                            '/', 1)[-1]] = pd.read_html(note)
                        sleep(3)
                    except HTTPError:
                        print('HTTP Error: Waiting 10 seconds and trying again'
                              ' for the current item')
                        sleep(10)
                        self.notes_dict[note.rsplit(
                            '/', 1)[-1]] = pd.read_html(note)
                        sleep(3)
                except HTTPError:
                    print('HTTP Error: Waiting 30 seconds and trying again'
                          ' for the current item')
                    sleep(30)
                    self.notes_dict[note.rsplit('/',
                                                1)[-1]] = pd.read_html(note)
                    sleep(3)
            except HTTPError:
                message = (f'Note {note} failed to read after 3 attemps.  '
                           'Logging for investigation.')
                self.errors_dict[(note, '__init__')] = message

        self.bmo_example_fields = pd.read_excel('BMO Examples.xlsx')
        self.pdw_df = self.bmo_example_fields[['PDW Fields']].copy()
        self.skip_cols = pd.Series(['Payment Schedule', 'Portfolio Summary'])

    # Get all scraping results as a single row table
    def transpose_set_header(self):

        # Additional fxn to recycle code
        def reassign_cols_truncate(self, key, i):
            self.notes_dict[key][i].columns = self.notes_dict[key][i].iloc[0]
            self.notes_dict[key][i] = self.notes_dict[key][i][1:]

        # This checks if the scrape results are a true table or not
        for key, val in self.notes_dict.items():
            for i in range(len(val)):
                if ~self.skip_cols.isin(self.notes_dict[key][i].columns).any():
                    self.notes_dict[key][i] = self.notes_dict[key][i].T
                    reassign_cols_truncate(self, key, i)
                else:
                    table_name = self.notes_dict[key][i].columns[0]
                    reassign_cols_truncate(self, key, i)
                    self.notes_dict[key][i].columns.name = table_name

    # Convert all to dict to navigate indices
    def label_note_tables(self):
        self.notes_dict = {
            key: {val[i].columns.name: val[i]
                  for i in range(len(val))}
            for key, val in self.notes_dict.items()
        }

    # Set PDW index
    def set_pdw_index(self):
        self.pdw_df.set_index('PDW Fields', inplace=True)

    # Rule: PDW Name
    def _PDW_Name(self):
        for key in self.notes_dict.keys():
            self.pdw_df[key] = None
            self.pdw_df.at['PDW Name',
                           key] = 'https://www.bmonotes.com/Note/' + key

    # Rule: callBarrierLevelFinal
    def _callBarrierLevelFinal(self):
        for key, val in self.notes_dict.items():
            # Check if right type of note
            try:
                if 'Payment Schedule' in val.keys():
                    if 'Autocall Level' in self.notes_dict[key][
                            'Payment Schedule'].columns:
                        # Replace '-' with NaN
                        self.notes_dict[key]['Payment Schedule'].replace(
                            '-', None, inplace=True, regex=False)

                        # Set filter to first non-null value
                        mask = ~self.notes_dict[key]['Payment Schedule'][
                            'Autocall Level'].isnull()

                        # Set value in the PDW table
                        self.pdw_df.at[
                            'productCall.callBarrierLevelFinal', key] = float(
                                self.notes_dict[key]['Payment Schedule']
                                ['Autocall Level'].loc[mask].iloc[0].strip(
                                    '%').replace(" ", "")) / 100
            except Exception as e:
                template = ("An exception of type {0} occurred. "
                            "Arguments:\n{1!r}")
                message = template.format(type(e).__name__, e.args)
                self.errors_dict[(key, '_callBarrierLevelFinal')] = (message,
                                                                     val)

    # Rule: callObservationDateList
    def _callObservationDateList(self):
        for key, val in self.notes_dict.items():
            # Check if right type of note
            try:
                if 'Payment Schedule' in val.keys():
                    if 'Observation Date' in val['Payment Schedule'].columns:
                        # Add the entire observation date column as a list
                        self.pdw_df.at[
                            'productCall.callObservationDateList',
                            key] = pd.to_datetime(
                                self.notes_dict[key]['Payment Schedule']
                                ['Observation Date']).dt.strftime(
                                    r'%Y-%m-%d').to_list()
                        self.pdw_df.at[
                            'productCall.callObservationDateList', key] = [{
                                'callObservationDate':
                                val
                            } for val in bmo.pdw_df.at[
                                'productCall.callObservationDateList', key]]

            except Exception as e:
                template = ("An exception of type {0} occurred. "
                            "Arguments:\n{1!r}")
                message = template.format(type(e).__name__, e.args)
                self.errors_dict[(key, '_callObservationDateList')] = (message,
                                                                       val)

    # Rule: callObservationFrequency
    def _callObservationFrequency(self):

        def check_call_freq(self, dt_days):
            if 2 <= dt_days <= 5:
                self.pdw_df.at['productCall.callObservationFrequency',
                               key] = 'Bi Weekly'
            if 6 <= dt_days <= 7:
                self.pdw_df.at['productCall.callObservationFrequency',
                               key] = 'Weekly'
            if 28 <= dt_days <= 31:
                self.pdw_df.at['productCall.callObservationFrequency',
                               key] = 'Monthly'
            elif 14 <= dt_days <= 16:
                self.pdw_df.at['productCall.callObservationFrequency',
                               key] = 'Bi Monthly'
            elif dt_days == 1:
                self.pdw_df.at['productCall.callObservationFrequency',
                               key] = 'Daily'
            elif 364 <= dt_days <= 366:
                self.pdw_df.at['productCall.callObservationFrequency',
                               key] = 'Annualy'
            elif 182 <= dt_days <= 184:
                self.pdw_df.at['productCall.callObservationFrequency',
                               key] = 'Semi Annualy'
            elif 89 <= dt_days <= 92:
                self.pdw_df.at['productCall.callObservationFrequency',
                               key] = 'Quarterly'
            else:
                self.pdw_df.at['productCall.callObservationFrequency',
                               key] = 'Custom'

        try:
            for key, val in self.notes_dict.items():
                # Check if right type of note
                if 'Payment Schedule' in val.keys():
                    if 'Observation Date' in val['Payment Schedule'].columns:
                        # Add the entire observation date column as a list
                        dt_diff = pd.to_datetime(
                            self.notes_dict[key]['Payment Schedule']
                            ['Observation Date'])
                        dt_diff = dt_diff - dt_diff.shift()
                        dt_days = dt_diff.mean().days
                        check_call_freq(self, dt_days)
        except Exception as e:
            template = ("An exception of type {0} occurred. "
                        "Arguments:\n{1!r}")
            message = template.format(type(e).__name__, e.args)
            self.errors_dict[(key, '_callObservationFrequency')] = (message,
                                                                    val)

    # Rule: callType
    def _callType(self):
        # Check if right type of note
        for key, val in self.notes_dict.items():
            try:
                if 'Payment Schedule' in val.keys():
                    if 'Autocall Level' in val['Payment Schedule'].columns:
                        # Check if all values are the same
                        autocall_series = self.notes_dict[
                            key]['Payment Schedule']['Autocall Level'].dropna(
                            ).reset_index(drop=True)
                        if (autocall_series == autocall_series[0]).all():
                            # self.pdw_df.at['productCall.callType', key] = 'Autocall'
                            self.pdw_df.at['productCall.callType',
                                           key] = 'Auto'
                        else:
                            # self.pdw_df.at['productCall.callType', key] = 'Auto Step'
                            self.pdw_df.at['productCall.callType',
                                           key] = 'Autocall Step'
            except Exception as e:
                template = ("An exception of type {0} occurred. "
                            "Arguments:\n{1!r}")
                message = template.format(type(e).__name__, e.args)
                self.errors_dict[(key, '_callType')] = (message, val)

    # Rule: numberNoCallPeriods
    def _numberNoCallPeriods(self):
        # Check if right type of note
        for key, val in self.notes_dict.items():
            try:
                if 'Payment Schedule' in val.keys():
                    if 'Autocall Level' in val['Payment Schedule'].columns:
                        # Filter to NaN + 1
                        self.pdw_df.at[
                            'productCall.numberNoCallPeriods', key] = len(
                                self.notes_dict[key]['Payment Schedule'].loc[
                                    self.notes_dict[key]['Payment Schedule']
                                    ['Autocall Level'].isna()]) + 1
            except Exception as e:
                template = ("An exception of type {0} occurred. "
                            "Arguments:\n{1!r}")
                message = template.format(type(e).__name__, e.args)
                self.errors_dict[(key, '_numberNoCallPeriods')] = (message,
                                                                   val)

    # Rule: currency
    def _currency(self):
        # Check if right type of note
        for key, val in self.notes_dict.items():
            try:
                if 'Product Details' in val.keys():
                    if 'Currency' in val['Product Details'].columns:
                        # Get currency column
                        self.pdw_df.at['productGeneral.currency',
                                       key] = self.notes_dict[key][
                                           'Product Details']['Currency'][0]
            except Exception as e:
                template = ("An exception of type {0} occurred. "
                            "Arguments:\n{1!r}")
                message = template.format(type(e).__name__, e.args)
                self.errors_dict[(key, '_currency')] = (message, val)

    # Rule: cusip
    def _cusip(self):
        # Check if right type of note
        for key, val in self.notes_dict.items():
            try:
                # Get JHN column and correct length
                if 'Product Details' in val.keys():
                    if 'JHN Code' in val['Product Details'].columns:
                        jhn = self.notes_dict[key]['Product Details'][
                            'JHN Code'][0]
                        if len(jhn) == 7:
                            self.pdw_df.at['productGeneral.cusip',
                                           key] = 'CA' + jhn
                        elif len(jhn) == 8:
                            self.pdw_df.at['productGeneral.cusip',
                                           key] = 'C' + jhn
                        else:
                            self.pdw_df.at['productGeneral.cusip', key] = jhn
            except Exception as e:
                template = ("An exception of type {0} occurred. "
                            "Arguments:\n{1!r}")
                message = template.format(type(e).__name__, e.args)
                self.errors_dict[(key, '_cusip')] = (message, val)

    # Rule: issueDate
    def _issueDate(self):
        # Check if right type of note
        for key, val in self.notes_dict.items():
            try:
                # Get date in right format
                if 'Product Details' in val.keys():
                    if 'Issue Date' in val['Product Details'].columns:
                        self.pdw_df.at[
                            'productGeneral.issueDate', key] = pd.to_datetime(
                                self.notes_dict[key]['Product Details']
                                ['Issue Date']).dt.strftime(r'%Y-%m-%d')[0]
            except Exception as e:
                template = ("An exception of type {0} occurred. "
                            "Arguments:\n{1!r}")
                message = template.format(type(e).__name__, e.args)
                self.errors_dict[(key, '_issueDate')] = (message, val)

    # Rule: issuer
    def _issuer(self):
        for key in self.notes_dict.keys():
            # Hardcode for now
            self.pdw_df.at['productGeneral.issuer', key] = 'Bank of Montreal'

    # Rule: maturityDate
    def _maturityDate(self):
        # Check if right type of note
        for key, val in self.notes_dict.items():
            try:
                # Get date in right format
                if 'Product Details' in val.keys():
                    if 'Maturity Date' in val['Product Details'].columns:
                        self.pdw_df.at[
                            'productGeneral.maturityDate',
                            key] = pd.to_datetime(
                                self.notes_dict[key]['Product Details']
                                ['Maturity Date']).dt.strftime(r'%Y-%m-%d')[0]
            except Exception as e:
                template = ("An exception of type {0} occurred. "
                            "Arguments:\n{1!r}")
                message = template.format(type(e).__name__, e.args)
                self.errors_dict[(key, '_maturityDate')] = (message, val)

    # Rule: productName
    def _productName(self):
        # Get title of webpages
        try:
            for key in self.notes_dict.keys():
                soup = BeautifulSoup(urlopen('https://www.bmonotes.com/Note/' +
                                             key),
                                     features="lxml")
                self.pdw_df.at['productGeneral.productName',
                               key] = str(soup.find_all('h1')[1]).replace(
                                   r'<h1>', '').replace(r'</h1>', '').strip()
        except Exception as e:
            template = ("An exception of type {0} occurred. "
                        "Arguments:\n{1!r}")
            message = template.format(type(e).__name__, e.args)
            self.errors_dict[(key, '_productName')] = message

    # Rule: stage
    def _stage(self):
        # Simple hardcode
        for key in self.notes_dict.keys():
            self.pdw_df.at['productGeneral.stage', key] = 'Ops Review'

    # Rule: status
    def _status(self):
        # Simple hardcode
        for key in self.notes_dict.keys():
            self.pdw_df.at['productGeneral.status',
                           key] = 'Update Product Details'

    # Rule: tenorFinal
    def _tenorFinal(self):
        # Get Term value
        for key, val in self.notes_dict.items():
            try:
                if 'Product Details' in val.keys():
                    if 'Term' in val['Product Details'].columns:
                        self.pdw_df.at['productGeneral.tenorFinal',
                                       key] = float(self.notes_dict[key]
                                                    ['Product Details']['Term']
                                                    [0].split()[0])
            except Exception as e:
                template = ("An exception of type {0} occurred. "
                            "Arguments:\n{1!r}")
                message = template.format(type(e).__name__, e.args)
                self.errors_dict[(key, '_tenorFinal')] = (message, val)

    # Rule: tenorUnit
    def _tenorUnit(self):
        # Get Term unit
        for key, val in self.notes_dict.items():
            try:
                if 'Product Details' in val.keys():
                    if 'Term' in val['Product Details'].columns:
                        self.pdw_df.at[
                            'productGeneral.tenorUnit',
                            key] = self.notes_dict[key]['Product Details'][
                                'Term'][0].split()[1].title()
            except Exception as e:
                template = ("An exception of type {0} occurred. "
                            "Arguments:\n{1!r}")
                message = template.format(type(e).__name__, e.args)
                self.errors_dict[(key, '_tenorUnit')] = (message, val)

    # Rule: underlierList
    def _underlierList(self):
        try:
            # Get value from table
            for key, val in self.notes_dict.items():
                if 'Product Details' in val.keys():
                    if 'Linked To' in val[
                            'Product Details'].columns and ',' in self.notes_dict[
                                key]['Product Details']['Linked To'][0]:
                        self.pdw_df.at[
                            'productGeneral.underlierList',
                            key] = self.notes_dict[key]['Product Details'][
                                'Linked To'][0].replace(' ', '').split(',')
                    else:
                        self.pdw_df.at['productGeneral.underlierList',
                                       key] = [{
                                           'underlierSymbol':
                                           self.notes_dict[key]
                                           ['Product Details']['Linked To'][0],
                                           'underlierWeight':
                                           1.0,
                                           'underlierSource':
                                           'Bloomberg',
                                       }]
        except Exception as e:
            template = ("An exception of type {0} occurred. "
                        "Arguments:\n{1!r}")
            message = template.format(type(e).__name__, e.args)
            self.errors_dict[(key, '_underlierList')] = (message, val)

    # Rule: underlierWeight
    def _underlierWeight(self):
        # Check for portfolio summary section and get weights
        for key, val in self.notes_dict.items():
            try:
                if 'Portfolio Summary' in val.keys():
                    if 'Share Weight' in val['Portfolio Summary'].columns:
                        underlier_weight = val['Portfolio Summary'].loc[
                            val['Portfolio Summary']['Share Weight'].str.
                            contains('%', na=False),
                            'Share Weight'].str.replace('%',
                                                        '').astype(float) / 100
                        self.pdw_df.at[
                            'productGeneral.underlierList.underlierWeight',
                            key] = underlier_weight.to_list()
            except Exception as e:
                template = ("An exception of type {0} occurred. "
                            "Arguments:\n{1!r}")
                message = template.format(type(e).__name__, e.args)
                self.errors_dict[(key, '_underlierWeight')] = (message, val)

    # Rule: upsideParticipationRateFinal
    def _upsideParticipationRateFinal(self):
        # Get value from table & convert to float
        try:
            for key, val in self.notes_dict.items():
                if 'Product Details' in val.keys():
                    if 'Upside Participation' in val[
                            'Product Details'].columns:
                        self.pdw_df.at[
                            'productGrowth.upsideParticipationRateFinal',
                            key] = float(
                                self.notes_dict[key]['Product Details']
                                ['Upside Participation'][0].replace(
                                    '-', '').replace('%', '')) / 100
                    elif 'Excess Participation' in val[
                            'Product Details'].columns:
                        self.pdw_df.at[
                            'productGrowth.upsideParticipationRateFinal',
                            key] = float(
                                self.notes_dict[key]['Product Details']
                                ['Excess Participation'][0].replace(
                                    '-', '').replace('%', '')) / 100
        except Exception as e:
            template = ("An exception of type {0} occurred. "
                        "Arguments:\n{1!r}")
            message = template.format(type(e).__name__, e.args)
            self.errors_dict[(key,
                              '_upsideParticipationRateFinal')] = (message,
                                                                   val)

    # Rule: principalBarrierLevelFinal
    def _principalBarrierLevelFinal(self):
        # Get value from table & convert to float
        for key, val in self.notes_dict.items():
            try:
                # These can be negative!
                if 'Product Details' in val.keys():
                    if 'Barrier Protection' in val['Product Details'].columns:
                        barrier_val = float(
                            self.notes_dict[key]['Product Details']
                            ['Barrier Protection'][0].replace('%', '').replace(
                                " ", "")) / 100
                        self.pdw_df.at[
                            'productProtection.principalBarrierLevelFinal',
                            key] = barrier_val + 1
                        self.pdw_df.at['productProtection.protectionLevel',
                                       key] = barrier_val * -1
                        self.pdw_df.at['productProtection.downsideType',
                                       key] = 'Barrier'
                        self.pdw_df.at['productProtection.putLeverageFinal',
                                       key] = 1
                        self.pdw_df.at['productProtection.putStrikeFinal',
                                       key] = barrier_val + 1
                    elif 'Buffer Protection' in val['Product Details'].columns:
                        buffer_val = float(
                            self.notes_dict[key]['Product Details']
                            ['Buffer Protection'][0].replace('%', '').replace(
                                " ", "")) / 100
                        self.pdw_df.at[
                            'productProtection.principalBufferLevelFinal',
                            key] = buffer_val * -1
                        self.pdw_df.at['productProtection.putStrikeFinal',
                                       key] = buffer_val + 1
                        self.pdw_df.at['productProtection.protectionLevel',
                                       key] = buffer_val * -1
                        self.pdw_df.at['productProtection.downsideType',
                                       key] = 'Buffer'
            except Exception as e:
                template = ("An exception of type {0} occurred. "
                            "Arguments:\n{1!r}")
                message = template.format(type(e).__name__, e.args)
                self.errors_dict[(key,
                                  '_principalBarrierLevelFinal')] = (message,
                                                                     val)

    # # Rule: countryDistribution
    # def _countryDistribution(self):
    #     # Hardcode
    #     for key in self.notes_dict.keys():
    #         self.pdw_df.at['productRegulatory.countryDistribution',
    #                        key] = 'CANADA'

    # Rule: paymentBarrierFinal
    def _paymentBarrierFinal(self):
        # Grab field from table & convert to float
        try:
            for key, val in self.notes_dict.items():
                if 'Product Details ' in val.keys():
                    if 'Coupon Knock-Out Level' in val[
                            'Product Details '].columns:
                        coupon_val = float(
                            self.notes_dict[key]['Indicative Return']
                            ['Coupon Knock-Out Level'][0].replace(
                                '-', '').replace('%', '').replace(" ",
                                                                  "")) / 100
                        self.pdw_df.at['productYield.paymentBarrierFinal',
                                       key] = coupon_val
                    elif 'Coupon Knock-In Level' in val[
                            'Product Details '].columns:
                        coupon_val = float(
                            self.notes_dict[key]['Indicative Return']
                            ['Coupon Knock-In Level'][0].replace(
                                '%', '').replace(" ", "")) / 100
                        self.pdw_df.at['productYield.paymentBarrierFinal',
                                       key] = coupon_val + 1
        except Exception as e:
            template = ("An exception of type {0} occurred. "
                        "Arguments:\n{1!r}")
            message = template.format(type(e).__name__, e.args)
            self.errors_dict[(key, '_paymentBarrierFinal')] = (message, val)

    # Rule: paymentDateList
    def _paymentDateList(self):
        # Add column as list
        for key, val in self.notes_dict.items():
            try:
                if 'Payment Schedule' in val.keys():
                    if 'Coupon Payment Date' in val[
                            'Payment Schedule'].columns:
                        self.pdw_df.at[
                            'productYield.paymentDateList',
                            key] = pd.to_datetime(
                                self.notes_dict[key]['Payment Schedule']
                                ['Coupon Payment Date']).dt.strftime(
                                    r'%Y-%m-%d').to_list()
                        self.pdw_df.at['productYield.paymentDateList',
                                       key] = [{
                                           'paymentDate': val
                                       } for val in bmo.pdw_df.at[
                                           'productYield.paymentDateList',
                                           key]]
            except Exception as e:
                template = ("An exception of type {0} occurred. "
                            "Arguments:\n{1!r}")
                message = template.format(type(e).__name__, e.args)
                self.errors_dict[(key, '_paymentDateList')] = (message, val)

    # Rule: paymentEvaluationFrequencyFinal
    def _paymentEvaluationFrequencyFinal(self):
        # If exists, static
        for key, val in self.notes_dict.items():
            try:
                if 'Product Details' in val.keys():
                    if 'Pay Frequency' in val['Product Details'].columns:
                        self.pdw_df.at[
                            'productYield.paymentEvaluationFrequencyFinal',
                            key] = self.notes_dict[key]['Product Details'][
                                'Pay Frequency'][0].title()
                        self.pdw_df.at[
                            'productYield.paymentFrequency',
                            key] = self.notes_dict[key]['Product Details'][
                                'Pay Frequency'][0].title()
                    elif 'Coupon Frequency' in val['Product Details'].columns:
                        self.pdw_df.at[
                            'productYield.paymentFrequency',
                            key] = self.notes_dict[key]['Product Details'][
                                'Coupon Frequency'][0].title()
            except Exception as e:
                template = ("An exception of type {0} occurred. "
                            "Arguments:\n{1!r}")
                message = template.format(type(e).__name__, e.args)
                self.errors_dict[(key, '_paymentEvaluationFrequencyFinal')] = (
                    message, val)

    # Rule: paymentRatePerAnnumFinal
    def _paymentRatePerAnnumFinal(self):
        # If exists, static & convert % to float
        for key, val in self.notes_dict.items():
            try:
                if 'Product Details' in val.keys():
                    if 'Contingent Coupon' in val['Product Details'].columns:
                        self.pdw_df.at[
                            'productYield.paymentRatePerAnnumFinal',
                            key] = float(
                                self.notes_dict[key]['Product Details']
                                ['Contingent Coupon'][0].replace(
                                    '-', '').replace('%', '').replace(
                                        " ", "")) / 100
            except Exception as e:
                template = ("An exception of type {0} occurred. "
                            "Arguments:\n{1!r}")
                message = template.format(type(e).__name__, e.args)
                self.errors_dict[(key,
                                  '_paymentRatePerAnnumFinal')] = (message,
                                                                   val)

    # Rule: paymentRatePerPeriodFinal
    def _paymentRatePerPeriodFinal(self):
        # Take previous rule results to calculate this if exists
        for col in self.pdw_df.columns:
            try:
                cond1 = self.pdw_df.at['productYield.paymentRatePerAnnumFinal',
                                       col] is not None
                cond2 = self.pdw_df.at['productYield.paymentFrequency',
                                       col] is not None
                cond3 = {
                    'Annualy': 1,
                    'Bi Monthly': 24,
                    'Bi Weekly': 104,
                    'Daily': 365,
                    'Monthly': 12,
                    'Quarterly': 4,
                    'Semi Annualy': 2,
                    'Weekly': 52,
                }
                if cond1 and cond2:
                    self.pdw_df.at['productYield.paymentRatePerPeriodFinal',
                                   col] = self.pdw_df.at[
                                       'productYield.paymentRatePerAnnumFinal',
                                       col] / cond3[self.pdw_df.at[
                                           'productYield.paymentFrequency',
                                           col]]
            except Exception as e:
                template = ("An exception of type {0} occurred. "
                            "Arguments:\n{1!r}")
                message = template.format(type(e).__name__, e.args)
                self.errors_dict[(col, 'paymentRatePerPeriodFinal')] = message

    # Rule: fundservID
    def _fundservID(self):
        # If exists, static
        for key, val in self.notes_dict.items():
            try:
                if 'Product Details' in val.keys():
                    if 'JHN Code' in val['Product Details'].columns:
                        self.pdw_df.at['productGeneral.fundservID',
                                       key] = self.notes_dict[key][
                                           'Product Details']['JHN Code'][0]
            except Exception as e:
                template = ("An exception of type {0} occurred. "
                            "Arguments:\n{1!r}")
                message = template.format(type(e).__name__, e.args)
                self.errors_dict[(key, '_fundservID')] = (message, val)

    # Rule: Mark to Market Price
    def _mark_to_market_price(self):
        # If exists, static & replace $, convert to float
        for key, val in self.notes_dict.items():
            try:
                if 'Current Status' in val.keys():
                    if 'Current Bid Price' in val['Current Status'].columns:
                        if val['Current Status']['Current Bid Price'][0] != '-':
                            self.pdw_df.at[
                                'Mark to Market Price', key] = float(
                                    self.notes_dict[key]['Current Status']
                                    ['Current Bid Price'][0].replace('$', ''))
            except Exception as e:
                template = ("An exception of type {0} occurred. "
                            "Arguments:\n{1!r}")
                message = template.format(type(e).__name__, e.args)
                self.errors_dict[(key, '_mark_to_market_price')] = (message,
                                                                    val)

    # Rule: minimumReturnFinal
    def _minimumReturnFinal(self):
        for key, val in self.notes_dict.items():
            try:
                if 'Product Details' in val.keys():
                    if 'Minimum Payment' in val['Product Details'].columns:
                        self.pdw_df.at[
                            'productGrowth.minimumReturnFinal', key] = float(
                                self.notes_dict[key]['Product Details']
                                ['Minimum Payment'][0].replace('$', ''))
            except Exception as e:
                template = ("An exception of type {0} occurred. "
                            "Arguments:\n{1!r}")
                message = template.format(type(e).__name__, e.args)
                self.errors_dict[(key, '_minimumReturnFinal')] = (message, val)

    # Rule: minimumReturnFinal
    def _tradeDate(self):
        for key, val in self.notes_dict.items():
            try:
                if 'Product Details' in val.keys():
                    if 'Available Until' in val['Product Details'].columns:
                        self.pdw_df.at[
                            'productGeneral.tradeDate', key] = pd.to_datetime(
                                self.notes_dict[key]['Product Details']
                                ['Available Until']).dt.strftime(
                                    r'%Y-%m-%d')[0]
            except Exception as e:
                template = ("An exception of type {0} occurred. "
                            "Arguments:\n{1!r}")
                message = template.format(type(e).__name__, e.args)
                self.errors_dict[(key, '_tradeDate')] = (message, val)

    # Rule: callPremiumFinal
    def _callPremiumFinal(self):
        for key, val in self.notes_dict.items():
            try:
                if 'Product Details' in val.keys():
                    if 'AutoCall Coupon (Next Call Date)' in val[
                            'Product Details'].columns:
                        self.pdw_df.at[
                            'productCall.callPremiumFinal', key] = float(
                                self.notes_dict[key]['Product Details']
                                ['AutoCall Coupon (Next Call Date)']
                                [0].replace('-', '').replace('%', '').replace(
                                    " ", "")) / 100
                        if self.pdw_df.at['productCall.callPremiumFinal',
                                          key] > 1:
                            self.pdw_df.at[
                                'productProtection.downsideType'] = 'Geared Buffer'
            except Exception as e:
                template = ("An exception of type {0} occurred. "
                            "Arguments:\n{1!r}")
                message = template.format(type(e).__name__, e.args)
                self.errors_dict[(key, '_callPremiumFinal')] = (message, val)

    # Rule: putLeverageFinal
    def _putLeverageFinal(self):
        for key, val in self.notes_dict.items():
            try:
                if 'Product Details' in val.keys():
                    if 'Downside Participation' in val[
                            'Product Details'].columns:
                        self.pdw_df.at[
                            'productProtection.putLeverageFinal', key] = float(
                                self.notes_dict[key]['Product Details']
                                ['Downside Participation'][0].replace(
                                    '-', '').replace('%', '').replace(
                                        " ", "")) / 100

            except Exception as e:
                template = ("An exception of type {0} occurred. "
                            "Arguments:\n{1!r}")
                message = template.format(type(e).__name__, e.args)
                self.errors_dict[(key, '_putLeverageFinal')] = (message, val)

    # Rule: extendibleNote
    def _extendibleNote(self):
        for key, val in self.notes_dict.items():
            try:
                if 'Product Details' in val.keys(
                ) and 'Rates Schedule' in val.keys():
                    if 'Product SubType' in val['Product Details'].columns:
                        if val['Product SubType'][
                                0] != 'Extendible Step-up Note':
                            if (val['Rate/Coupon'] == val['Rate/Coupon'][0]
                                ).all():
                                rate_coupon_val = float(
                                    self.notes_dict[key]['Rates Schedule']
                                    ['Rate/Coupon'][0].replace(
                                        '%', '').replace(" ", "")) / 100
                                self.pdw_df.at[
                                    'productYield.paymentRatePerPeriodFinal',
                                    key] = rate_coupon_val
                                dt_diff = pd.to_datetime(
                                    self.notes_dict[key]['Rates Schedule']
                                    ['From (including)'])
                                dt_diff = dt_diff - dt_diff.shift()
                                dt_days = dt_diff.mean().days
                                self.pdw_df.at[
                                    'productYield.paymentRatePerAnnumFinal'] = rate_coupon_val / dt_days
                                self.pdw_df.at[
                                    'productYield.paymentDateList'] = pd.to_datetime(
                                        self.notes_dict[key]['Rates Schedule']
                                        ['From (including)']).dt.strftime(
                                            r'%Y-%m-%d').to_list()
                                self.pdw_df.at[
                                    'productYield.paymentDateList', key] = [{
                                        'paymentDate':
                                        val
                                    } for val in bmo.pdw_df.at[
                                        'productYield.paymentDateList', key]]

            except Exception as e:
                template = ("An exception of type {0} occurred. "
                            "Arguments:\n{1!r}")
                message = template.format(type(e).__name__, e.args)
                self.errors_dict[(key, '_putLeverageFinal')] = (message, val)

    # Run all rules
    def run_all_rules(self):
        self.transpose_set_header()
        self.label_note_tables()
        self.set_pdw_index()
        self._PDW_Name()
        self._callBarrierLevelFinal()
        self._callObservationDateList()
        self._callObservationFrequency()
        self._callType()
        self._numberNoCallPeriods()
        self._currency()
        self._cusip()
        self._issueDate()
        self._issuer()
        self._maturityDate()
        self._productName()
        self._stage()
        self._status()
        self._tenorFinal()
        self._tenorUnit()
        self._underlierList()
        self._underlierWeight()
        self._upsideParticipationRateFinal()
        self._principalBarrierLevelFinal()
        # self._countryDistribution()
        self._paymentBarrierFinal()
        self._paymentDateList()
        self._paymentEvaluationFrequencyFinal()
        self._paymentRatePerAnnumFinal()
        self._paymentRatePerPeriodFinal()
        self._fundservID()
        self._mark_to_market_price()
        self._minimumReturnFinal()
        self._tradeDate()
        self._callPremiumFinal()
        self._putLeverageFinal()
        self._extendibleNote()

    def reset_pdw_indices(self):
        # Reset indices to prepare to JSON
        try:
            self.pdw_insert_df = self.pdw_df.copy()
            self.pdw_insert_df.drop(['PDW Name', 'Mark to Market Price'],
                                    inplace=True)
            self.pdw_insert_df.dropna(subset=self.pdw_df.columns,
                                      how='all',
                                      inplace=True)
            self.pdw_insert_df.reset_index(inplace=True)
        except Exception as e:
            template = ("An exception of type {0} occurred. "
                        "Arguments:\n{1!r}")
            message = template.format(type(e).__name__, e.args)
            self.errors_dict[(self.pdw_insert_df,
                              'reset_pdw_indices')] = message

    def process_pdw_dicts(self):
        # Process for JSON
        self.pdw_df_dict = {}
        for col in self.pdw_df.columns:
            try:
                self.pdw_df_dict[col] = self.pdw_insert_df[['PDW Fields',
                                                            col]].dropna()
                self.pdw_df_dict[col] = pd.concat(
                    [
                        self.pdw_df_dict[col]['PDW Fields'].str.split(
                            '.', expand=True), self.pdw_df_dict[col]
                    ],
                    axis=1,
                )
                self.pdw_df_dict[col].drop(columns='PDW Fields', inplace=True)
            except Exception as e:
                template = ("An exception of type {0} occurred. "
                            "Arguments:\n{1!r}")
                message = template.format(type(e).__name__, e.args)
                self.errors_dict[(col, 'process_pdw_dicts')] = message

    def insert_pdw_json_to_pdw(self):
        # Convert to JSON & set up cxn
        self.result = {}
        # db = self.client['test-masking-dev']
        # PdwProductCore = db.PdwProductCore
        for col in self.pdw_df_dict.keys():
            try:
                len_cols = list(range(len(self.pdw_df_dict[col].columns) - 1))
                pdw_pre_insert = self.pdw_df_dict[col].set_index(
                    len_cols).groupby(level=0).apply(
                        lambda x: x.xs(x.name)[col].to_dict()).to_dict()

                # Prepare underlier list
                if ('underlierList',
                        nan) in pdw_pre_insert['productGeneral'].keys() and (
                            'underlierList', 'underlierWeight'
                        ) in pdw_pre_insert['productGeneral'].keys():
                    pdw_pre_insert['productGeneral']['underlierList'] = []
                    for sym, weight in zip(
                            pdw_pre_insert['productGeneral'][('underlierList',
                                                              nan)],
                            pdw_pre_insert['productGeneral'][(
                                'underlierList', 'underlierWeight')]):
                        pdw_pre_insert['productGeneral'][
                            'underlierList'].append({
                                'underlierSymbol':
                                sym,
                                'underlierWeight':
                                weight,
                                'underlierSource':
                                'Bloomberg'
                            })
                    del pdw_pre_insert['productGeneral'][('underlierList',
                                                          nan)]
                    del pdw_pre_insert['productGeneral'][('underlierList',
                                                          'underlierWeight')]

                # Prepare final JSON
                pdw_insert = {}
                for key, val in pdw_pre_insert.items():
                    pdw_insert[key] = {}
                    for key2, val2 in val.items():
                        if isinstance(key2, tuple):
                            if isinstance(key2[1], str):
                                pdw_insert[key][key2[0]] = {key2[1]: val2}
                            else:
                                pdw_insert[key][key2[0]] = val2
                        else:
                            pdw_insert[key][key2] = val2

                # Final JSON assertions
                required_fields = [
                    'productProtection',
                    'productCall',
                    'productYield',
                    'productGrowth',
                    # 'productGeneral.wrapperType',
                ]
                for field in required_fields:
                    if field not in pdw_insert.keys():
                        pdw_insert[field] = {}
                if 'wrapperType' not in pdw_insert['productGeneral'].keys():
                    pdw_insert['productGeneral']['wrapperType'] = 'Note'

                # Insert into DB
                # try:
                # self.result[col] = (PdwProductCore.insert_one(pdw_insert),
                #                     pdw_insert)
                #     self.result[col] = pdw_insert
                # except DuplicateKeyError:
                #     self.result[col] = ('Product exists', pdw_insert)
                self.result[col] = pdw_insert
            except Exception as e:
                template = ("An exception of type {0} occurred. "
                            "Arguments:\n{1!r}")
                message = template.format(type(e).__name__, e.args)
                self.errors_dict[(col, 'insert_pdw_json_to_pdw')] = message

    def write_to_pdw(self):
        # The writing process as one method
        self.reset_pdw_indices()
        self.process_pdw_dicts()
        self.insert_pdw_json_to_pdw()

# %%
# with open('urls_to_pdw.txt') as f:
#     bmo_urls = f.read().splitlines()
# bmo_urls_sample = sample(bmo_urls, 50)
bmo_urls_sample = [
    'https://www.bmonotes.com/Note/JHN7482',
    'https://www.bmonotes.com/Note/JHN15954',
    'https://www.bmonotes.com/Note/JHN15093',
    'https://www.bmonotes.com/Note/JHN2058',
    'https://www.bmonotes.com/Note/JHN15992',
]
user = 'skimble'
password = get_password('docdb_preprod', user)
host = "dev-documentdb.cluster-cb6kajicuplh.us-east-1.docdb.amazonaws.com"
port = "27017"
options = ("tls=true&tlsAllowInvalidCertificates=true&replicaSet=rs0&"
           "readPreference=secondaryPreferred&retryWrites=false")

# %%
bmo = BmoScraper(bmo_urls_sample, user, password, host, port, options)

# %%
bmo.run_all_rules()

# %%
pd.set_option('display.max_rows', 200)
bmo.pdw_df
# Out:
#                                                                                               JHN7482  \
# PDW Fields
# PDW Name                                                        https://www.bmonotes.com/Note/JHN7482
# productCall.callBarrierLevelCurrent                                                              None
# productCall.callBarrierLevelFinal                                                                None
# productCall.callBarrierLevelUnderlierList                                                        None
# productCall.callBarrierStepIncrement                                                             None
# productCall.callObservationDateList                                                              None
# productCall.callObservationFrequency                                                             None
# productCall.callPeriodObservationType                                                            None
# productCall.callPremiumCurrent                                                                   None
# productCall.callPremiumFinal                                                                     None
# productCall.callPremiumStepIncrement                                                             None
# productCall.callType                                                                             None
# productCall.expectedMaturity                                                                     None
# productCall.numberNoCallPeriods                                                                  None
# productCall.stepType                                                                             None
# productGeneral.accountType                                                                       None
# productGeneral.ancillaryFeatures                                                                 None
# productGeneral.assetClass                                                                        None
# productGeneral.averagingExclusion                                                                None
# productGeneral.averagingInDates                                                                  None
# productGeneral.averagingModified                                                                 None
# productGeneral.averagingOutDates                                                                 None
# productGeneral.basketReturnAdjustment                                                            None
# productGeneral.basketType                                                                        None
# productGeneral.bidDeadlineTimestamp                                                              None
# productGeneral.businessDayConvention                                                             None
# productGeneral.calculationAgent                                                                  None
# productGeneral.completionStatus                                                                  None
# productGeneral.currency                                                                           CAD
# productGeneral.cusip                                                                        CAJHN7482
# productGeneral.dayCountFraction                                                                  None
# productGeneral.estimatedInitialValue                                                             None
# productGeneral.externalDocumentProvider.externa...                                               None
# productGeneral.externalDocumentProvider.legalRe...                                               None
# productGeneral.externalDocumentProvider.secLink                                                  None
# productGeneral.externalDocumentProvider.taxReview                                                None
# productGeneral.fairPriceFinal                                                                    None
# productGeneral.fdicInsured                                                                       None
# productGeneral.finalValuationDate                                                                None
# productGeneral.fundingSpread                                                                     None
# productGeneral.isin                                                                              None
# productGeneral.issueDate                                                                   2022-01-21
# productGeneral.issuePriceFinal                                                                   None
# productGeneral.issuer                                                                Bank of Montreal
# productGeneral.longTermCapitalGain                                                               None
# productGeneral.lookbackFinalDate                                                                 None
# productGeneral.lookbackFinalValuationType                                                        None
# productGeneral.lookbackInitialDate                                                               None
# productGeneral.lookbackInitialValuationType                                                      None
# productGeneral.maturityDate                                                                2025-01-21
# productGeneral.minimumTradingLot                                                                 None
# productGeneral.offeringType                                                                      None
# productGeneral.originator                                                                        None
# productGeneral.productDeadlineTimestamp                                                          None
# productGeneral.productFaceValue                                                                  None
# productGeneral.productLaunchTimestamp                                                            None
# productGeneral.productName                          BMO Accelerator Principal At Risk Notes, Serie...
# productGeneral.productNoteList                                                                   None
# productGeneral.productNotionalCap                                                                None
# productGeneral.productNotionalCurrent                                                            None
# productGeneral.productNotionalFinal                                                              None
# productGeneral.productRiskRanking                                                                None
# productGeneral.registrationType                                                                  None
# productGeneral.reofferClientList                                                                 None
# productGeneral.requestId                                                                         None
# productGeneral.returnType                                                                        None
# productGeneral.riskFreeRate                                                                      None
# productGeneral.salesCreditFinal                                                                  None
# productGeneral.secondaryMarketQuotingType                                                        None
# productGeneral.settlementType                                                                    None
# productGeneral.sspaStructureTypeId                                                               None
# productGeneral.sspaStructureTypeName                                                             None
# productGeneral.stage                                                                       Ops Review
# productGeneral.standardPrice                                                                     None
# productGeneral.status                                                          Update Product Details
# productGeneral.strikeDate                                                                        None
# productGeneral.structureFee                                                                      None
# productGeneral.structureNameExternal                                                             None
# productGeneral.structureNameInternal                                                             None
# productGeneral.structureShortNameExternal                                                        None
# productGeneral.structureShortNameInternal                                                        None
# productGeneral.supplementalPercentage                                                            None
# productGeneral.swapMaturity                                                                      None
# productGeneral.tenorCurrent                                                                      None
# productGeneral.tenorFinal                                                                         3.0
# productGeneral.tenorUnit                                                                        Years
# productGeneral.totalPnl                                                                          None
# productGeneral.tradeDate                                                                         None
# productGeneral.underlierList                        [{'underlierSymbol': 'Solactive Equal Weight C...
# productGeneral.underlierList.underlierWeight                                                     None
# productGeneral.upfrontDeferred                                                                   None
# productGeneral.wrapperType                                                                       None
# productGrowth.absoluteReturnBarrierLevelFinal                                                    None
# productGrowth.absoluteReturnParticipationRateFinal                                               None
# productGrowth.bearish                                                                            None
# productGrowth.digitalReturnBarrierCurrent                                                        None
# productGrowth.digitalReturnBarrierFinal                                                          None
# productGrowth.digitalReturnBarrierObservationDa...                                               None
# productGrowth.digitalReturnBarrierObservationFr...                                               None
# productGrowth.digitalReturnFinal                                                                 None
# productGrowth.growthType                                                                         None
# productGrowth.knockOutBarrierFinal                                                               None
# productGrowth.knockOutRebateFinal                                                                None
# productGrowth.lowerCallStrikeFinal                                                               None
# productGrowth.lowerPutStrike                                                                     None
# productGrowth.maximumReturnFinal                                                                 None
# productGrowth.minimumReturnFinal                                                                  1.0
# productGrowth.underlierReturnCapLevelFinal                                                       None
# productGrowth.upsideAboveDigitalReturn                                                           None
# productGrowth.upsideParticipationAboveDigitalRe...                                               None
# productGrowth.upsideParticipationAboveDigitalRe...                                               None
# productGrowth.upsideParticipationRateFinal                                                        3.0
# productId                                                                                        None
# productProtection.capitalProtectionLevelCurrent                                                  None
# productProtection.capitalProtectionLevelFinal                                                    None
# productProtection.downsideType                                                                   None
# productProtection.principalBarrierLevelCurrent                                                   None
# productProtection.principalBarrierLevelFinal                                                     None
# productProtection.principalBarrierLevelUnderlie...                                               None
# productProtection.principalBufferLevelFinal                                                      None
# productProtection.protectionLevel                                                                None
# productProtection.putLeverageCurrent                                                             None
# productProtection.putLeverageFinal                                                               None
# productProtection.putObservationDateList                                                         None
# productProtection.putObservationFrequency                                                        None
# productProtection.putStrikeFinal                                                                 None
# productProtection.putType                                                                        None
# productRegulatory.countryDistribution                                                            None
# productRegulatory.listing                                                                        None
# productRegulatory.supportingDocumentation                                                        None
# productRegulatory.targetMarket                                                                   None
# productYield.floatSpread                                                                         None
# productYield.interest                                                                            None
# productYield.leverageFactors                                                                     None
# productYield.minCouponPayPeriod                                                                  None
# productYield.minPaymentRatePerAnnumFinal                                                         None
# productYield.minPaymentRatePerPeriodFinal                                                        None
# productYield.optionPremium                                                                       None
# productYield.paymentBarrierCurrent                                                               None
# productYield.paymentBarrierFinal                                                                 None
# productYield.paymentBarrierObservationFrequency                                                  None
# productYield.paymentBarrierUnderlierList                                                         None
# productYield.paymentDateList                                                                     None
# productYield.paymentEvaluationFrequencyCurrent                                                   None
# productYield.paymentEvaluationFrequencyFinal                                                     None
# productYield.paymentFrequency                                                                    None
# productYield.paymentMemory                                                                       None
# productYield.paymentRatePerAnnumFinal                                                            None
# productYield.paymentRatePerPeriodCurrent                                                         None
# productYield.paymentRatePerPeriodFinal                                                           None
# productYield.paymentType                                                                         None
# productYield.paymentTypeChangeDate                                                               None
# productYield.rateBuilderGrouping                                                                 None
# productYield.rateBuilderReturns                                                                  None
# productYield.rateBuilderValuesFinal                                                              None
# productYield.stockReturnCapFinal                                                                 None
# productYield.stockReturnFloorFinal                                                               None
# productYield.upperBarrierLevelFinal                                                              None
# productYield.variablePayFinalObservationDate                                                     None
# productYield.variablePayInitialObservationDate                                                   None
# version                                                                                          None
# productgeneral.fundservID                                                                        None
# Mark to Market Price                                                                            82.92
# Must Store Call and Payment Observation Dates                                                    None
# productGeneral.fundservID                                                                     JHN7482
#
#                                                                                              JHN15954  \
# PDW Fields
# PDW Name                                                       https://www.bmonotes.com/Note/JHN15954
# productCall.callBarrierLevelCurrent                                                              None
# productCall.callBarrierLevelFinal                                                                1.05
# productCall.callBarrierLevelUnderlierList                                                        None
# productCall.callBarrierStepIncrement                                                             None
# productCall.callObservationDateList                 [{'callObservationDate': '2022-08-22'}, {'call...
# productCall.callObservationFrequency                                                          Monthly
# productCall.callPeriodObservationType                                                            None
# productCall.callPremiumCurrent                                                                   None
# productCall.callPremiumFinal                                                                     None
# productCall.callPremiumStepIncrement                                                             None
# productCall.callType                                                                             Auto
# productCall.expectedMaturity                                                                     None
# productCall.numberNoCallPeriods                                                                     6
# productCall.stepType                                                                             None
# productGeneral.accountType                                                                       None
# productGeneral.ancillaryFeatures                                                                 None
# productGeneral.assetClass                                                                        None
# productGeneral.averagingExclusion                                                                None
# productGeneral.averagingInDates                                                                  None
# productGeneral.averagingModified                                                                 None
# productGeneral.averagingOutDates                                                                 None
# productGeneral.basketReturnAdjustment                                                            None
# productGeneral.basketType                                                                        None
# productGeneral.bidDeadlineTimestamp                                                              None
# productGeneral.businessDayConvention                                                             None
# productGeneral.calculationAgent                                                                  None
# productGeneral.completionStatus                                                                  None
# productGeneral.currency                                                                           CAD
# productGeneral.cusip                                                                        CJHN15954
# productGeneral.dayCountFraction                                                                  None
# productGeneral.estimatedInitialValue                                                             None
# productGeneral.externalDocumentProvider.externa...                                               None
# productGeneral.externalDocumentProvider.legalRe...                                               None
# productGeneral.externalDocumentProvider.secLink                                                  None
# productGeneral.externalDocumentProvider.taxReview                                                None
# productGeneral.fairPriceFinal                                                                    None
# productGeneral.fdicInsured                                                                       None
# productGeneral.finalValuationDate                                                                None
# productGeneral.fundingSpread                                                                     None
# productGeneral.isin                                                                              None
# productGeneral.issueDate                                                                   2022-07-27
# productGeneral.issuePriceFinal                                                                   None
# productGeneral.issuer                                                                Bank of Montreal
# productGeneral.longTermCapitalGain                                                               None
# productGeneral.lookbackFinalDate                                                                 None
# productGeneral.lookbackFinalValuationType                                                        None
# productGeneral.lookbackInitialDate                                                               None
# productGeneral.lookbackInitialValuationType                                                      None
# productGeneral.maturityDate                                                                2029-07-27
# productGeneral.minimumTradingLot                                                                 None
# productGeneral.offeringType                                                                      None
# productGeneral.originator                                                                        None
# productGeneral.productDeadlineTimestamp                                                          None
# productGeneral.productFaceValue                                                                  None
# productGeneral.productLaunchTimestamp                                                            None
# productGeneral.productName                          Bank of Montreal Canadian Energy Callable Equi...
# productGeneral.productNoteList                                                                   None
# productGeneral.productNotionalCap                                                                None
# productGeneral.productNotionalCurrent                                                            None
# productGeneral.productNotionalFinal                                                              None
# productGeneral.productRiskRanking                                                                None
# productGeneral.registrationType                                                                  None
# productGeneral.reofferClientList                                                                 None
# productGeneral.requestId                                                                         None
# productGeneral.returnType                                                                        None
# productGeneral.riskFreeRate                                                                      None
# productGeneral.salesCreditFinal                                                                  None
# productGeneral.secondaryMarketQuotingType                                                        None
# productGeneral.settlementType                                                                    None
# productGeneral.sspaStructureTypeId                                                               None
# productGeneral.sspaStructureTypeName                                                             None
# productGeneral.stage                                                                       Ops Review
# productGeneral.standardPrice                                                                     None
# productGeneral.status                                                          Update Product Details
# productGeneral.strikeDate                                                                        None
# productGeneral.structureFee                                                                      None
# productGeneral.structureNameExternal                                                             None
# productGeneral.structureNameInternal                                                             None
# productGeneral.structureShortNameExternal                                                        None
# productGeneral.structureShortNameInternal                                                        None
# productGeneral.supplementalPercentage                                                            None
# productGeneral.swapMaturity                                                                      None
# productGeneral.tenorCurrent                                                                      None
# productGeneral.tenorFinal                                                                         7.0
# productGeneral.tenorUnit                                                                        Years
# productGeneral.totalPnl                                                                          None
# productGeneral.tradeDate                                                                         None
# productGeneral.underlierList                                                           [CNQ, CVE, SU]
# productGeneral.underlierList.underlierWeight                                 [0.3333, 0.3333, 0.3333]
# productGeneral.upfrontDeferred                                                                   None
# productGeneral.wrapperType                                                                       None
# productGrowth.absoluteReturnBarrierLevelFinal                                                    None
# productGrowth.absoluteReturnParticipationRateFinal                                               None
# productGrowth.bearish                                                                            None
# productGrowth.digitalReturnBarrierCurrent                                                        None
# productGrowth.digitalReturnBarrierFinal                                                          None
# productGrowth.digitalReturnBarrierObservationDa...                                               None
# productGrowth.digitalReturnBarrierObservationFr...                                               None
# productGrowth.digitalReturnFinal                                                                 None
# productGrowth.growthType                                                                         None
# productGrowth.knockOutBarrierFinal                                                               None
# productGrowth.knockOutRebateFinal                                                                None
# productGrowth.lowerCallStrikeFinal                                                               None
# productGrowth.lowerPutStrike                                                                     None
# productGrowth.maximumReturnFinal                                                                 None
# productGrowth.minimumReturnFinal                                                                 None
# productGrowth.underlierReturnCapLevelFinal                                                       None
# productGrowth.upsideAboveDigitalReturn                                                           None
# productGrowth.upsideParticipationAboveDigitalRe...                                               None
# productGrowth.upsideParticipationAboveDigitalRe...                                               None
# productGrowth.upsideParticipationRateFinal                                                       None
# productId                                                                                        None
# productProtection.capitalProtectionLevelCurrent                                                  None
# productProtection.capitalProtectionLevelFinal                                                    None
# productProtection.downsideType                                                                Barrier
# productProtection.principalBarrierLevelCurrent                                                   None
# productProtection.principalBarrierLevelFinal                                                      0.6
# productProtection.principalBarrierLevelUnderlie...                                               None
# productProtection.principalBufferLevelFinal                                                      None
# productProtection.protectionLevel                                                                 0.4
# productProtection.putLeverageCurrent                                                             None
# productProtection.putLeverageFinal                                                                  1
# productProtection.putObservationDateList                                                         None
# productProtection.putObservationFrequency                                                        None
# productProtection.putStrikeFinal                                                                  0.6
# productProtection.putType                                                                        None
# productRegulatory.countryDistribution                                                            None
# productRegulatory.listing                                                                        None
# productRegulatory.supportingDocumentation                                                        None
# productRegulatory.targetMarket                                                                   None
# productYield.floatSpread                                                                         None
# productYield.interest                                                                            None
# productYield.leverageFactors                                                                     None
# productYield.minCouponPayPeriod                                                                  None
# productYield.minPaymentRatePerAnnumFinal                                                         None
# productYield.minPaymentRatePerPeriodFinal                                                        None
# productYield.optionPremium                                                                       None
# productYield.paymentBarrierCurrent                                                               None
# productYield.paymentBarrierFinal                                                                 None
# productYield.paymentBarrierObservationFrequency                                                  None
# productYield.paymentBarrierUnderlierList                                                         None
# productYield.paymentDateList                        [{'paymentDate': '2022-08-29'}, {'paymentDate'...
# productYield.paymentEvaluationFrequencyCurrent                                                   None
# productYield.paymentEvaluationFrequencyFinal                                                  Monthly
# productYield.paymentFrequency                                                                 Monthly
# productYield.paymentMemory                                                                       None
# productYield.paymentRatePerAnnumFinal                                                          0.1179
# productYield.paymentRatePerPeriodCurrent                                                         None
# productYield.paymentRatePerPeriodFinal                                                       0.009825
# productYield.paymentType                                                                         None
# productYield.paymentTypeChangeDate                                                               None
# productYield.rateBuilderGrouping                                                                 None
# productYield.rateBuilderReturns                                                                  None
# productYield.rateBuilderValuesFinal                                                              None
# productYield.stockReturnCapFinal                                                                 None
# productYield.stockReturnFloorFinal                                                               None
# productYield.upperBarrierLevelFinal                                                              None
# productYield.variablePayFinalObservationDate                                                     None
# productYield.variablePayInitialObservationDate                                                   None
# version                                                                                          None
# productgeneral.fundservID                                                                        None
# Mark to Market Price                                                                            102.3
# Must Store Call and Payment Observation Dates                                                    None
# productGeneral.fundservID                                                                    JHN15954
#
#                                                                                              JHN15093  \
# PDW Fields
# PDW Name                                                       https://www.bmonotes.com/Note/JHN15093
# productCall.callBarrierLevelCurrent                                                              None
# productCall.callBarrierLevelFinal                                                                 1.0
# productCall.callBarrierLevelUnderlierList                                                        None
# productCall.callBarrierStepIncrement                                                             None
# productCall.callObservationDateList                 [{'callObservationDate': '2022-11-29'}, {'call...
# productCall.callObservationFrequency                                                          Annualy
# productCall.callPeriodObservationType                                                            None
# productCall.callPremiumCurrent                                                                   None
# productCall.callPremiumFinal                                                                   0.0899
# productCall.callPremiumStepIncrement                                                             None
# productCall.callType                                                                             Auto
# productCall.expectedMaturity                                                                     None
# productCall.numberNoCallPeriods                                                                     1
# productCall.stepType                                                                             None
# productGeneral.accountType                                                                       None
# productGeneral.ancillaryFeatures                                                                 None
# productGeneral.assetClass                                                                        None
# productGeneral.averagingExclusion                                                                None
# productGeneral.averagingInDates                                                                  None
# productGeneral.averagingModified                                                                 None
# productGeneral.averagingOutDates                                                                 None
# productGeneral.basketReturnAdjustment                                                            None
# productGeneral.basketType                                                                        None
# productGeneral.bidDeadlineTimestamp                                                              None
# productGeneral.businessDayConvention                                                             None
# productGeneral.calculationAgent                                                                  None
# productGeneral.completionStatus                                                                  None
# productGeneral.currency                                                                           CAD
# productGeneral.cusip                                                                        CJHN15093
# productGeneral.dayCountFraction                                                                  None
# productGeneral.estimatedInitialValue                                                             None
# productGeneral.externalDocumentProvider.externa...                                               None
# productGeneral.externalDocumentProvider.legalRe...                                               None
# productGeneral.externalDocumentProvider.secLink                                                  None
# productGeneral.externalDocumentProvider.taxReview                                                None
# productGeneral.fairPriceFinal                                                                    None
# productGeneral.fdicInsured                                                                       None
# productGeneral.finalValuationDate                                                                None
# productGeneral.fundingSpread                                                                     None
# productGeneral.isin                                                                              None
# productGeneral.issueDate                                                                   2021-12-06
# productGeneral.issuePriceFinal                                                                   None
# productGeneral.issuer                                                                Bank of Montreal
# productGeneral.longTermCapitalGain                                                               None
# productGeneral.lookbackFinalDate                                                                 None
# productGeneral.lookbackFinalValuationType                                                        None
# productGeneral.lookbackInitialDate                                                               None
# productGeneral.lookbackInitialValuationType                                                      None
# productGeneral.maturityDate                                                                2028-12-06
# productGeneral.minimumTradingLot                                                                 None
# productGeneral.offeringType                                                                      None
# productGeneral.originator                                                                        None
# productGeneral.productDeadlineTimestamp                                                          None
# productGeneral.productFaceValue                                                                  None
# productGeneral.productLaunchTimestamp                                                            None
# productGeneral.productName                          BMO AutoCallable Buffer Notes, Series 1819 (CA...
# productGeneral.productNoteList                                                                   None
# productGeneral.productNotionalCap                                                                None
# productGeneral.productNotionalCurrent                                                            None
# productGeneral.productNotionalFinal                                                              None
# productGeneral.productRiskRanking                                                                None
# productGeneral.registrationType                                                                  None
# productGeneral.reofferClientList                                                                 None
# productGeneral.requestId                                                                         None
# productGeneral.returnType                                                                        None
# productGeneral.riskFreeRate                                                                      None
# productGeneral.salesCreditFinal                                                                  None
# productGeneral.secondaryMarketQuotingType                                                        None
# productGeneral.settlementType                                                                    None
# productGeneral.sspaStructureTypeId                                                               None
# productGeneral.sspaStructureTypeName                                                             None
# productGeneral.stage                                                                       Ops Review
# productGeneral.standardPrice                                                                     None
# productGeneral.status                                                          Update Product Details
# productGeneral.strikeDate                                                                        None
# productGeneral.structureFee                                                                      None
# productGeneral.structureNameExternal                                                             None
# productGeneral.structureNameInternal                                                             None
# productGeneral.structureShortNameExternal                                                        None
# productGeneral.structureShortNameInternal                                                        None
# productGeneral.supplementalPercentage                                                            None
# productGeneral.swapMaturity                                                                      None
# productGeneral.tenorCurrent                                                                      None
# productGeneral.tenorFinal                                                                         7.0
# productGeneral.tenorUnit                                                                        Years
# productGeneral.totalPnl                                                                          None
# productGeneral.tradeDate                                                                         None
# productGeneral.underlierList                        [{'underlierSymbol': 'Solactive Canada Insuran...
# productGeneral.underlierList.underlierWeight                                                     None
# productGeneral.upfrontDeferred                                                                   None
# productGeneral.wrapperType                                                                       None
# productGrowth.absoluteReturnBarrierLevelFinal                                                    None
# productGrowth.absoluteReturnParticipationRateFinal                                               None
# productGrowth.bearish                                                                            None
# productGrowth.digitalReturnBarrierCurrent                                                        None
# productGrowth.digitalReturnBarrierFinal                                                          None
# productGrowth.digitalReturnBarrierObservationDa...                                               None
# productGrowth.digitalReturnBarrierObservationFr...                                               None
# productGrowth.digitalReturnFinal                                                                 None
# productGrowth.growthType                                                                         None
# productGrowth.knockOutBarrierFinal                                                               None
# productGrowth.knockOutRebateFinal                                                                None
# productGrowth.lowerCallStrikeFinal                                                               None
# productGrowth.lowerPutStrike                                                                     None
# productGrowth.maximumReturnFinal                                                                 None
# productGrowth.minimumReturnFinal                                                                 None
# productGrowth.underlierReturnCapLevelFinal                                                       None
# productGrowth.upsideAboveDigitalReturn                                                           None
# productGrowth.upsideParticipationAboveDigitalRe...                                               None
# productGrowth.upsideParticipationAboveDigitalRe...                                               None
# productGrowth.upsideParticipationRateFinal                                                       0.05
# productId                                                                                        None
# productProtection.capitalProtectionLevelCurrent                                                  None
# productProtection.capitalProtectionLevelFinal                                                    None
# productProtection.downsideType                                                                 Buffer
# productProtection.principalBarrierLevelCurrent                                                   None
# productProtection.principalBarrierLevelFinal                                                     None
# productProtection.principalBarrierLevelUnderlie...                                               None
# productProtection.principalBufferLevelFinal                                                       0.2
# productProtection.protectionLevel                                                                 0.2
# ...
# productCall.expectedMaturity                                                                     None
# productCall.numberNoCallPeriods                                                                     6
# productCall.stepType                                                                             None
# productGeneral.accountType                                                                       None
# productGeneral.ancillaryFeatures                                                                 None
# productGeneral.assetClass                                                                        None
# productGeneral.averagingExclusion                                                                None
# productGeneral.averagingInDates                                                                  None
# productGeneral.averagingModified                                                                 None
# productGeneral.averagingOutDates                                                                 None
# productGeneral.basketReturnAdjustment                                                            None
# productGeneral.basketType                                                                        None
# productGeneral.bidDeadlineTimestamp                                                              None
# productGeneral.businessDayConvention                                                             None
# productGeneral.calculationAgent                                                                  None
# productGeneral.completionStatus                                                                  None
# productGeneral.currency                                                                           CAD
# productGeneral.cusip                                                                        CJHN15992
# productGeneral.dayCountFraction                                                                  None
# productGeneral.estimatedInitialValue                                                             None
# productGeneral.externalDocumentProvider.externa...                                               None
# productGeneral.externalDocumentProvider.legalRe...                                               None
# productGeneral.externalDocumentProvider.secLink                                                  None
# productGeneral.externalDocumentProvider.taxReview                                                None
# productGeneral.fairPriceFinal                                                                    None
# productGeneral.fdicInsured                                                                       None
# productGeneral.finalValuationDate                                                                None
# productGeneral.fundingSpread                                                                     None
# productGeneral.isin                                                                              None
# productGeneral.issueDate                                                                   2022-07-14
# productGeneral.issuePriceFinal                                                                   None
# productGeneral.issuer                                                                Bank of Montreal
# productGeneral.longTermCapitalGain                                                               None
# productGeneral.lookbackFinalDate                                                                 None
# productGeneral.lookbackFinalValuationType                                                        None
# productGeneral.lookbackInitialDate                                                               None
# productGeneral.lookbackInitialValuationType                                                      None
# productGeneral.maturityDate                                                                2027-07-14
# productGeneral.minimumTradingLot                                                                 None
# productGeneral.offeringType                                                                      None
# productGeneral.originator                                                                        None
# productGeneral.productDeadlineTimestamp                                                          None
# productGeneral.productFaceValue                                                                  None
# productGeneral.productLaunchTimestamp                                                            None
# productGeneral.productName                          BMO Callable Buffer Income Notes, Series 3501 ...
# productGeneral.productNoteList                                                                   None
# productGeneral.productNotionalCap                                                                None
# productGeneral.productNotionalCurrent                                                            None
# productGeneral.productNotionalFinal                                                              None
# productGeneral.productRiskRanking                                                                None
# productGeneral.registrationType                                                                  None
# productGeneral.reofferClientList                                                                 None
# productGeneral.requestId                                                                         None
# productGeneral.returnType                                                                        None
# productGeneral.riskFreeRate                                                                      None
# productGeneral.salesCreditFinal                                                                  None
# productGeneral.secondaryMarketQuotingType                                                        None
# productGeneral.settlementType                                                                    None
# productGeneral.sspaStructureTypeId                                                               None
# productGeneral.sspaStructureTypeName                                                             None
# productGeneral.stage                                                                       Ops Review
# productGeneral.standardPrice                                                                     None
# productGeneral.status                                                          Update Product Details
# productGeneral.strikeDate                                                                        None
# productGeneral.structureFee                                                                      None
# productGeneral.structureNameExternal                                                             None
# productGeneral.structureNameInternal                                                             None
# productGeneral.structureShortNameExternal                                                        None
# productGeneral.structureShortNameInternal                                                        None
# productGeneral.supplementalPercentage                                                            None
# productGeneral.swapMaturity                                                                      None
# productGeneral.tenorCurrent                                                                      None
# productGeneral.tenorFinal                                                                         5.0
# productGeneral.tenorUnit                                                                        Years
# productGeneral.totalPnl                                                                          None
# productGeneral.tradeDate                                                                         None
# productGeneral.underlierList                        [{'underlierSymbol': 'Tesla', 'underlierWeight...
# productGeneral.underlierList.underlierWeight                                                     None
# productGeneral.upfrontDeferred                                                                   None
# productGeneral.wrapperType                                                                       None
# productGrowth.absoluteReturnBarrierLevelFinal                                                    None
# productGrowth.absoluteReturnParticipationRateFinal                                               None
# productGrowth.bearish                                                                            None
# productGrowth.digitalReturnBarrierCurrent                                                        None
# productGrowth.digitalReturnBarrierFinal                                                          None
# productGrowth.digitalReturnBarrierObservationDa...                                               None
# productGrowth.digitalReturnBarrierObservationFr...                                               None
# productGrowth.digitalReturnFinal                                                                 None
# productGrowth.growthType                                                                         None
# productGrowth.knockOutBarrierFinal                                                               None
# productGrowth.knockOutRebateFinal                                                                None
# productGrowth.lowerCallStrikeFinal                                                               None
# productGrowth.lowerPutStrike                                                                     None
# productGrowth.maximumReturnFinal                                                                 None
# productGrowth.minimumReturnFinal                                                                 None
# productGrowth.underlierReturnCapLevelFinal                                                       None
# productGrowth.upsideAboveDigitalReturn                                                           None
# productGrowth.upsideParticipationAboveDigitalRe...                                               None
# productGrowth.upsideParticipationAboveDigitalRe...                                               None
# productGrowth.upsideParticipationRateFinal                                                       None
# productId                                                                                        None
# productProtection.capitalProtectionLevelCurrent                                                  None
# productProtection.capitalProtectionLevelFinal                                                    None
# productProtection.downsideType                                                                 Buffer
# productProtection.principalBarrierLevelCurrent                                                   None
# productProtection.principalBarrierLevelFinal                                                     None
# productProtection.principalBarrierLevelUnderlie...                                               None
# productProtection.principalBufferLevelFinal                                                       0.3
# productProtection.protectionLevel                                                                 0.3
# productProtection.putLeverageCurrent                                                             None
# productProtection.putLeverageFinal                                                             1.4286
# productProtection.putObservationDateList                                                         None
# productProtection.putObservationFrequency                                                        None
# productProtection.putStrikeFinal                                                                  0.7
# productProtection.putType                                                                        None
# productRegulatory.countryDistribution                                                            None
# productRegulatory.listing                                                                        None
# productRegulatory.supportingDocumentation                                                        None
# productRegulatory.targetMarket                                                                   None
# productYield.floatSpread                                                                         None
# productYield.interest                                                                            None
# productYield.leverageFactors                                                                     None
# productYield.minCouponPayPeriod                                                                  None
# productYield.minPaymentRatePerAnnumFinal                                                         None
# productYield.minPaymentRatePerPeriodFinal                                                        None
# productYield.optionPremium                                                                       None
# productYield.paymentBarrierCurrent                                                               None
# productYield.paymentBarrierFinal                                                                 None
# productYield.paymentBarrierObservationFrequency                                                  None
# productYield.paymentBarrierUnderlierList                                                         None
# productYield.paymentDateList                        [{'paymentDate': '2022-08-15'}, {'paymentDate'...
# productYield.paymentEvaluationFrequencyCurrent                                                   None
# productYield.paymentEvaluationFrequencyFinal                                                  Monthly
# productYield.paymentFrequency                                                                 Monthly
# productYield.paymentMemory                                                                       None
# productYield.paymentRatePerAnnumFinal                                                          0.2592
# productYield.paymentRatePerPeriodCurrent                                                         None
# productYield.paymentRatePerPeriodFinal                                                         0.0216
# productYield.paymentType                                                                         None
# productYield.paymentTypeChangeDate                                                               None
# productYield.rateBuilderGrouping                                                                 None
# productYield.rateBuilderReturns                                                                  None
# productYield.rateBuilderValuesFinal                                                              None
# productYield.stockReturnCapFinal                                                                 None
# productYield.stockReturnFloorFinal                                                               None
# productYield.upperBarrierLevelFinal                                                              None
# productYield.variablePayFinalObservationDate                                                     None
# productYield.variablePayInitialObservationDate                                                   None
# version                                                                                          None
# productgeneral.fundservID                                                                        None
# Mark to Market Price                                                                           106.04
# Must Store Call and Payment Observation Dates                                                    None
# productGeneral.fundservID                                                                    JHN15992

# %%
bmo.write_to_pdw()
bmo.result
# Out:
# {'JHN7482': {'productGeneral': {'currency': 'CAD',
#    'cusip': 'CAJHN7482',
#    'issueDate': '2022-01-21',
#    'issuer': 'Bank of Montreal',
#    'maturityDate': '2025-01-21',
#    'productName': 'BMO Accelerator Principal At Risk Notes, Series 128 (CAD) Linked to Solactive Equal Weight Canada Banks 5% AR Index',
#    'stage': 'Ops Review',
#    'status': 'Update Product Details',
#    'tenorFinal': 3.0,
#    'tenorUnit': 'Years',
#    'underlierList': [{'underlierSymbol': 'Solactive Equal Weight Canada Banks 5% AR Index',
#      'underlierWeight': 1.0,
#      'underlierSource': 'Bloomberg'}],
#    'fundservID': 'JHN7482',
#    'wrapperType': 'Note'},
#   'productGrowth': {'minimumReturnFinal': 1.0,
#    'upsideParticipationRateFinal': 3.0},
#   'productProtection': {},
#   'productCall': {},
#   'productYield': {}},
#  'JHN15954': {'productCall': {'callBarrierLevelFinal': 1.05,
#    'callObservationDateList': [{'callObservationDate': '2022-08-22'},
#     {'callObservationDate': '2022-09-20'},
#     {'callObservationDate': '2022-10-20'},
#     {'callObservationDate': '2022-11-21'},
#     {'callObservationDate': '2022-12-19'},
#     {'callObservationDate': '2023-01-20'},
#     {'callObservationDate': '2023-02-17'},
#     {'callObservationDate': '2023-03-20'},
#     {'callObservationDate': '2023-04-20'},
#     {'callObservationDate': '2023-05-19'},
#     {'callObservationDate': '2023-06-20'},
#     {'callObservationDate': '2023-07-20'},
#     {'callObservationDate': '2023-08-21'},
#     {'callObservationDate': '2023-09-20'},
#     {'callObservationDate': '2023-10-20'},
#     {'callObservationDate': '2023-11-20'},
#     {'callObservationDate': '2023-12-18'},
#     {'callObservationDate': '2024-01-22'},
#     {'callObservationDate': '2024-02-20'},
#     {'callObservationDate': '2024-03-20'},
#     {'callObservationDate': '2024-04-22'},
#     {'callObservationDate': '2024-05-17'},
#     {'callObservationDate': '2024-06-20'},
#     {'callObservationDate': '2024-07-22'},
#     {'callObservationDate': '2024-08-20'},
#     {'callObservationDate': '2024-09-20'},
#     {'callObservationDate': '2024-10-21'},
#     {'callObservationDate': '2024-11-20'},
#     {'callObservationDate': '2024-12-18'},
#     {'callObservationDate': '2025-01-20'},
#     {'callObservationDate': '2025-02-20'},
#     {'callObservationDate': '2025-03-20'},
#     {'callObservationDate': '2025-04-21'},
#     {'callObservationDate': '2025-05-20'},
#     {'callObservationDate': '2025-06-20'},
#     {'callObservationDate': '2025-07-21'},
#     {'callObservationDate': '2025-08-20'},
#     {'callObservationDate': '2025-09-22'},
#     {'callObservationDate': '2025-10-20'},
#     {'callObservationDate': '2025-11-20'},
#     {'callObservationDate': '2025-12-18'},
#     {'callObservationDate': '2026-01-20'},
#     {'callObservationDate': '2026-02-20'},
#     {'callObservationDate': '2026-03-20'},
#     {'callObservationDate': '2026-04-20'},
#     {'callObservationDate': '2026-05-20'},
#     {'callObservationDate': '2026-06-22'},
#     {'callObservationDate': '2026-07-20'},
#     {'callObservationDate': '2026-08-20'},
#     {'callObservationDate': '2026-09-21'},
#     {'callObservationDate': '2026-10-20'},
#     {'callObservationDate': '2026-11-20'},
#     {'callObservationDate': '2026-12-18'},
#     {'callObservationDate': '2027-01-20'},
#     {'callObservationDate': '2027-02-22'},
#     {'callObservationDate': '2027-03-19'},
#     {'callObservationDate': '2027-04-20'},
#     {'callObservationDate': '2027-05-19'},
#     {'callObservationDate': '2027-06-21'},
#     {'callObservationDate': '2027-07-20'},
#     {'callObservationDate': '2027-08-20'},
#     {'callObservationDate': '2027-09-20'},
#     {'callObservationDate': '2027-10-20'},
#     {'callObservationDate': '2027-11-22'},
#     {'callObservationDate': '2027-12-20'},
#     {'callObservationDate': '2028-01-20'},
#     {'callObservationDate': '2028-02-18'},
#     {'callObservationDate': '2028-03-20'},
#     {'callObservationDate': '2028-04-20'},
#     {'callObservationDate': '2028-05-19'},
#     {'callObservationDate': '2028-06-20'},
#     {'callObservationDate': '2028-07-20'},
#     {'callObservationDate': '2028-08-21'},
#     {'callObservationDate': '2028-09-20'},
#     {'callObservationDate': '2028-10-20'},
#     {'callObservationDate': '2028-11-20'},
#     {'callObservationDate': '2028-12-18'},
#     {'callObservationDate': '2029-01-22'},
#     {'callObservationDate': '2029-02-20'},
#     {'callObservationDate': '2029-03-20'},
#     {'callObservationDate': '2029-04-20'},
#     {'callObservationDate': '2029-05-18'},
#     {'callObservationDate': '2029-06-20'},
#     {'callObservationDate': '2029-07-20'}],
#    'callObservationFrequency': 'Monthly',
#    'callType': 'Auto',
#    'numberNoCallPeriods': 6},
#   'productGeneral': {'currency': 'CAD',
#    'cusip': 'CJHN15954',
#    'issueDate': '2022-07-27',
#    'issuer': 'Bank of Montreal',
#    'maturityDate': '2029-07-27',
#    'productName': 'Bank of Montreal Canadian Energy Callable Equity Income Principal At Risk Notes, Series 3471 (CAD)',
#    'stage': 'Ops Review',
#    'status': 'Update Product Details',
#    'tenorFinal': 7.0,
#    'tenorUnit': 'Years',
#    'fundservID': 'JHN15954',
#    'underlierList': [{'underlierSymbol': 'CNQ',
#      'underlierWeight': 0.3333,
#      'underlierSource': 'Bloomberg'},
#     {'underlierSymbol': 'CVE',
#      'underlierWeight': 0.3333,
#      'underlierSource': 'Bloomberg'},
#     {'underlierSymbol': 'SU',
#      'underlierWeight': 0.3333,
#      'underlierSource': 'Bloomberg'}],
#    'wrapperType': 'Note'},
#   'productProtection': {'downsideType': 'Barrier',
#    'principalBarrierLevelFinal': 0.6,
#    'protectionLevel': 0.4,
#    'putLeverageFinal': 1,
#    'putStrikeFinal': 0.6},
#   'productYield': {'paymentDateList': [{'paymentDate': '2022-08-29'},
#     {'paymentDate': '2022-09-27'},
#     {'paymentDate': '2022-10-27'},
#     {'paymentDate': '2022-11-28'},
#     {'paymentDate': '2022-12-28'},
#     {'paymentDate': '2023-01-27'},
#     {'paymentDate': '2023-02-27'},
#     {'paymentDate': '2023-03-27'},
#     {'paymentDate': '2023-04-27'},
#     {'paymentDate': '2023-05-29'},
#     {'paymentDate': '2023-06-27'},
#     {'paymentDate': '2023-07-27'},
#     {'paymentDate': '2023-08-28'},
#     {'paymentDate': '2023-09-27'},
#     {'paymentDate': '2023-10-27'},
#     {'paymentDate': '2023-11-27'},
#     {'paymentDate': '2023-12-27'},
#     {'paymentDate': '2024-01-29'},
#     {'paymentDate': '2024-02-27'},
#     {'paymentDate': '2024-03-27'},
#     {'paymentDate': '2024-04-29'},
#     {'paymentDate': '2024-05-27'},
#     {'paymentDate': '2024-06-27'},
#     {'paymentDate': '2024-07-29'},
#     {'paymentDate': '2024-08-27'},
#     {'paymentDate': '2024-09-27'},
#     {'paymentDate': '2024-10-28'},
#     {'paymentDate': '2024-11-27'},
#     {'paymentDate': '2024-12-27'},
#     {'paymentDate': '2025-01-27'},
#     {'paymentDate': '2025-02-27'},
#     {'paymentDate': '2025-03-27'},
#     {'paymentDate': '2025-04-28'},
#     {'paymentDate': '2025-05-27'},
#     {'paymentDate': '2025-06-27'},
#     {'paymentDate': '2025-07-28'},
#     {'paymentDate': '2025-08-27'},
#     {'paymentDate': '2025-09-29'},
#     {'paymentDate': '2025-10-27'},
#     {'paymentDate': '2025-11-27'},
#     {'paymentDate': '2025-12-29'},
#     {'paymentDate': '2026-01-27'},
#     {'paymentDate': '2026-02-27'},
#     {'paymentDate': '2026-03-27'},
#     {'paymentDate': '2026-04-27'},
#     {'paymentDate': '2026-05-27'},
#     {'paymentDate': '2026-06-29'},
#     {'paymentDate': '2026-07-27'},
#     {'paymentDate': '2026-08-27'},
#     {'paymentDate': '2026-09-28'},
#     {'paymentDate': '2026-10-27'},
#     {'paymentDate': '2026-11-27'},
#     {'paymentDate': '2026-12-29'},
#     {'paymentDate': '2027-01-27'},
#     {'paymentDate': '2027-03-01'},
#     {'paymentDate': '2027-03-29'},
#     {'paymentDate': '2027-04-27'},
#     {'paymentDate': '2027-05-27'},
#     {'paymentDate': '2027-06-28'},
#     {'paymentDate': '2027-07-27'},
#     {'paymentDate': '2027-08-27'},
#     {'paymentDate': '2027-09-27'},
#     {'paymentDate': '2027-10-27'},
#     {'paymentDate': '2027-11-29'},
#     {'paymentDate': '2027-12-29'},
#     {'paymentDate': '2028-01-27'},
#     {'paymentDate': '2028-02-28'},
#     {'paymentDate': '2028-03-27'},
#     {'paymentDate': '2028-04-27'},
#     {'paymentDate': '2028-05-29'},
#     {'paymentDate': '2028-06-27'},
#     {'paymentDate': '2028-07-27'},
#     {'paymentDate': '2028-08-28'},
#     {'paymentDate': '2028-09-27'},
#     {'paymentDate': '2028-10-27'},
#     {'paymentDate': '2028-11-27'},
#     {'paymentDate': '2028-12-27'},
#     {'paymentDate': '2029-01-29'},
#     {'paymentDate': '2029-02-27'},
#     {'paymentDate': '2029-03-27'},
#     {'paymentDate': '2029-04-27'},
#     {'paymentDate': '2029-05-28'},
#     {'paymentDate': '2029-06-27'},
#     {'paymentDate': '2029-07-27'}],
#    'paymentEvaluationFrequencyFinal': 'Monthly',
#    'paymentFrequency': 'Monthly',
#    'paymentRatePerAnnumFinal': 0.11789999999999999,
#    'paymentRatePerPeriodFinal': 0.009824999999999999},
#   'productGrowth': {}},
#  'JHN15093': {'productCall': {'callBarrierLevelFinal': 1.0,
#    'callObservationDateList': [{'callObservationDate': '2022-11-29'},
#     {'callObservationDate': '2023-11-29'},
#     {'callObservationDate': '2024-11-29'},
#     {'callObservationDate': '2025-12-01'},
#     {'callObservationDate': '2026-11-30'},
#     {'callObservationDate': '2027-11-29'},
#     {'callObservationDate': '2028-11-29'}],
#    'callObservationFrequency': 'Annualy',
#    'callPremiumFinal': 0.08990000000000001,
#    'callType': 'Auto',
#    'numberNoCallPeriods': 1},
#   'productGeneral': {'currency': 'CAD',
#    'cusip': 'CJHN15093',
#    'issueDate': '2021-12-06',
#    'issuer': 'Bank of Montreal',
#    'maturityDate': '2028-12-06',
#    'productName': 'BMO AutoCallable Buffer Notes, Series 1819 (CAD),  Linked to Solactive Canada Insurance AR Index',
#    'stage': 'Ops Review',
#    'status': 'Update Product Details',
#    'tenorFinal': 7.0,
#    'tenorUnit': 'Years',
#    'underlierList': [{'underlierSymbol': 'Solactive Canada Insurance AR Index',
#      'underlierWeight': 1.0,
#      'underlierSource': 'Bloomberg'}],
#    'fundservID': 'JHN15093',
#    'wrapperType': 'Note'},
#   'productGrowth': {'upsideParticipationRateFinal': 0.05},
#   'productProtection': {'downsideType': 'Buffer',
#    'principalBufferLevelFinal': 0.2,
#    'protectionLevel': 0.2,
#    'putLeverageFinal': 1.25,
#    'putStrikeFinal': 0.8},
#   'productYield': {}},
#  'JHN2058': {'productGeneral': {'currency': 'CAD',
#    'cusip': 'CAJHN2058',
#    'issueDate': '2017-05-17',
#    'issuer': 'Bank of Montreal',
#    'maturityDate': '2024-05-17',
#    'productName': 'Bank of Montreal Advantage Minimum Y.I.E.L.D. Seven Year Principal Protected Deposit Notes, Series 21',
#    'stage': 'Ops Review',
#    'status': 'Update Product Details',
#    'tenorFinal': 7.0,
#    'tenorUnit': 'Years',
#    'fundservID': 'JHN2058',
#    'underlierList': [{'underlierSymbol': 'CJR/B',
#      'underlierWeight': 0.1,
#      'underlierSource': 'Bloomberg'},
#     {'underlierSymbol': 'CM',
#      'underlierWeight': 0.1,
#      'underlierSource': 'Bloomberg'},
#     {'underlierSymbol': 'ENB',
#      'underlierWeight': 0.1,
#      'underlierSource': 'Bloomberg'},
#     {'underlierSymbol': 'KEY',
#      'underlierWeight': 0.1,
#      'underlierSource': 'Bloomberg'},
#     {'underlierSymbol': 'NTR',
#      'underlierWeight': 0.2,
#      'underlierSource': 'Bloomberg'},
#     {'underlierSymbol': 'POW',
#      'underlierWeight': 0.1,
#      'underlierSource': 'Bloomberg'},
#     {'underlierSymbol': 'SU',
#      'underlierWeight': 0.1,
#      'underlierSource': 'Bloomberg'},
#     {'underlierSymbol': 'TA',
#      'underlierWeight': 0.1,
#      'underlierSource': 'Bloomberg'},
#     {'underlierSymbol': 'TECK/B',
#      'underlierWeight': 0.1,
#      'underlierSource': 'Bloomberg'}],
#    'wrapperType': 'Note'},
#   'productProtection': {},
#   'productCall': {},
#   'productYield': {},
#   'productGrowth': {}},
#  'JHN15992': {'productCall': {'callBarrierLevelFinal': 1.05,
#    'callObservationDateList': [{'callObservationDate': '2022-08-08'},
#     {'callObservationDate': '2022-09-07'},
#     {'callObservationDate': '2022-10-06'},
#     {'callObservationDate': '2022-11-04'},
#     {'callObservationDate': '2022-12-07'},
#     {'callObservationDate': '2023-01-09'},
#     {'callObservationDate': '2023-02-07'},
#     {'callObservationDate': '2023-03-07'},
#     {'callObservationDate': '2023-04-06'},
#     {'callObservationDate': '2023-05-08'},
#     {'callObservationDate': '2023-06-07'},
#     {'callObservationDate': '2023-07-07'},
#     {'callObservationDate': '2023-08-04'},
#     {'callObservationDate': '2023-09-07'},
#     {'callObservationDate': '2023-10-06'},
#     {'callObservationDate': '2023-11-06'},
#     {'callObservationDate': '2023-12-07'},
#     {'callObservationDate': '2024-01-08'},
#     {'callObservationDate': '2024-02-07'},
#     {'callObservationDate': '2024-03-07'},
#     {'callObservationDate': '2024-04-08'},
#     {'callObservationDate': '2024-05-07'},
#     {'callObservationDate': '2024-06-07'},
#     {'callObservationDate': '2024-07-08'},
#     {'callObservationDate': '2024-08-07'},
#     {'callObservationDate': '2024-09-09'},
#     {'callObservationDate': '2024-10-07'},
#     {'callObservationDate': '2024-11-06'},
#     {'callObservationDate': '2024-12-09'},
#     {'callObservationDate': '2025-01-07'},
#     {'callObservationDate': '2025-02-07'},
#     {'callObservationDate': '2025-03-07'},
#     {'callObservationDate': '2025-04-07'},
#     {'callObservationDate': '2025-05-07'},
#     {'callObservationDate': '2025-06-09'},
#     {'callObservationDate': '2025-07-07'},
#     {'callObservationDate': '2025-08-07'},
#     {'callObservationDate': '2025-09-08'},
#     {'callObservationDate': '2025-10-06'},
#     {'callObservationDate': '2025-11-06'},
#     {'callObservationDate': '2025-12-08'},
#     {'callObservationDate': '2026-01-07'},
#     {'callObservationDate': '2026-02-09'},
#     {'callObservationDate': '2026-03-09'},
#     {'callObservationDate': '2026-04-07'},
#     {'callObservationDate': '2026-05-07'},
#     {'callObservationDate': '2026-06-08'},
#     {'callObservationDate': '2026-07-07'},
#     {'callObservationDate': '2026-08-07'},
#     {'callObservationDate': '2026-09-04'},
#     {'callObservationDate': '2026-10-06'},
#     {'callObservationDate': '2026-11-06'},
#     {'callObservationDate': '2026-12-07'},
#     {'callObservationDate': '2027-01-07'},
#     {'callObservationDate': '2027-02-08'},
#     {'callObservationDate': '2027-03-08'},
#     {'callObservationDate': '2027-04-07'},
#     {'callObservationDate': '2027-05-07'},
#     {'callObservationDate': '2027-06-07'},
#     {'callObservationDate': '2027-07-07'}],
#    'callObservationFrequency': 'Monthly',
#    'callType': 'Auto',
#    'numberNoCallPeriods': 6},
#   'productGeneral': {'currency': 'CAD',
#    'cusip': 'CJHN15992',
#    'issueDate': '2022-07-14',
#    'issuer': 'Bank of Montreal',
#    'maturityDate': '2027-07-14',
#    'productName': 'BMO Callable Buffer Income Notes, Series 3501 (CAD) (F-Class) Linked to Tesla, Inc.',
#    'stage': 'Ops Review',
#    'status': 'Update Product Details',
#    'tenorFinal': 5.0,
#    'tenorUnit': 'Years',
#    'underlierList': [{'underlierSymbol': 'Tesla',
#      'underlierWeight': 1.0,
#      'underlierSource': 'Bloomberg'}],
#    'fundservID': 'JHN15992',
#    'wrapperType': 'Note'},
#   'productProtection': {'downsideType': 'Buffer',
#    'principalBufferLevelFinal': 0.3,
#    'protectionLevel': 0.3,
#    'putLeverageFinal': 1.4286,
#    'putStrikeFinal': 0.7},
#   'productYield': {'paymentDateList': [{'paymentDate': '2022-08-15'},
#     {'paymentDate': '2022-09-14'},
#     {'paymentDate': '2022-10-14'},
#     {'paymentDate': '2022-11-14'},
#     {'paymentDate': '2022-12-14'},
#     {'paymentDate': '2023-01-16'},
#     {'paymentDate': '2023-02-14'},
#     {'paymentDate': '2023-03-14'},
#     {'paymentDate': '2023-04-14'},
#     {'paymentDate': '2023-05-15'},
#     {'paymentDate': '2023-06-14'},
#     {'paymentDate': '2023-07-14'},
#     {'paymentDate': '2023-08-14'},
#     {'paymentDate': '2023-09-14'},
#     {'paymentDate': '2023-10-16'},
#     {'paymentDate': '2023-11-14'},
#     {'paymentDate': '2023-12-14'},
#     {'paymentDate': '2024-01-15'},
#     {'paymentDate': '2024-02-14'},
#     {'paymentDate': '2024-03-14'},
#     {'paymentDate': '2024-04-15'},
#     {'paymentDate': '2024-05-14'},
#     {'paymentDate': '2024-06-14'},
#     {'paymentDate': '2024-07-15'},
#     {'paymentDate': '2024-08-14'},
#     {'paymentDate': '2024-09-16'},
#     {'paymentDate': '2024-10-15'},
#     {'paymentDate': '2024-11-14'},
#     {'paymentDate': '2024-12-16'},
#     {'paymentDate': '2025-01-14'},
#     {'paymentDate': '2025-02-14'},
#     {'paymentDate': '2025-03-14'},
#     {'paymentDate': '2025-04-14'},
#     {'paymentDate': '2025-05-14'},
#     {'paymentDate': '2025-06-16'},
#     {'paymentDate': '2025-07-14'},
#     {'paymentDate': '2025-08-14'},
#     {'paymentDate': '2025-09-15'},
#     {'paymentDate': '2025-10-14'},
#     {'paymentDate': '2025-11-14'},
#     {'paymentDate': '2025-12-15'},
#     {'paymentDate': '2026-01-14'},
#     {'paymentDate': '2026-02-17'},
#     {'paymentDate': '2026-03-16'},
#     {'paymentDate': '2026-04-14'},
#     {'paymentDate': '2026-05-14'},
#     {'paymentDate': '2026-06-15'},
#     {'paymentDate': '2026-07-14'},
#     {'paymentDate': '2026-08-14'},
#     {'paymentDate': '2026-09-14'},
#     {'paymentDate': '2026-10-14'},
#     {'paymentDate': '2026-11-16'},
#     {'paymentDate': '2026-12-14'},
#     {'paymentDate': '2027-01-14'},
#     {'paymentDate': '2027-02-16'},
#     {'paymentDate': '2027-03-15'},
#     {'paymentDate': '2027-04-14'},
#     {'paymentDate': '2027-05-14'},
#     {'paymentDate': '2027-06-14'},
#     {'paymentDate': '2027-07-14'}],
#    'paymentEvaluationFrequencyFinal': 'Monthly',
#    'paymentFrequency': 'Monthly',
#    'paymentRatePerAnnumFinal': 0.25920000000000004,
#    'paymentRatePerPeriodFinal': 0.021600000000000005},
#   'productGrowth': {}}}

# %%
bmo.errors_dict
# Out:
# {}
